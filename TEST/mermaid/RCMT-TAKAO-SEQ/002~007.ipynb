# %% [markdown]
# # RCMT-TAKAO-SEQ002-E210-每一段都分開
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[NOT-DB0049] -->|TRUE| C1
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[NOT-DI0052] -->|TRUE| C2
#         B2[NOT-DI0050] -->|TRUE| C2
#         G2[IN0154] -->|TRUE| C2
#         H2[IN0165] -->|TRUE| C2
#         I2[IN0166] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF03判斷
#         A3[IN0168] -->|TRUE| C3
#         B3[IN0169] -->|TRUE| C3
#         D3[IN0170] -->|TRUE| C3
#         G3[IN0171] -->|TRUE| C3
#         H3[IN0172] -->|TRUE| C3
#         I3[IN0173] -->|TRUE| C3
#         C3{任一訊號為TRUE} -->|TRUE| E3[MF03 = TRUE]
#         C3 -->|FALSE| F3[MF03 維持 FALSE]
#     end
#
#     %% MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     E3 --> C4
#     C4 -->|TRUE| K4[K1 = TRUE]
#     C4 -->|FALSE| K5[K1 維持 FALSE]

# %% [markdown]
# # RCMT-TAKAO-SEQ002-E210-沒有將每個模組分開的情況
#
# ```mermaid
# flowchart LR
#     subgraph SEQ001 判斷流程
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1 -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#
#         A2[NOT-DI0052] -->|TRUE| C2{任一訊號為TRUE}
#         B2[NOT-DI0050] -->|TRUE| C2
#         G2[IN0154] -->|TRUE| C2
#         H2[IN0165] -->|TRUE| C2
#         I2[IN0166] -->|TRUE| C2
#         C2 -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#
#         A3[IN0168] -->|TRUE| C3{任一訊號為TRUE}
#         B3[IN0169] -->|TRUE| C3
#         D3[IN0170] -->|TRUE| C3
#         G3[IN0171] -->|TRUE| C3
#         H3[IN0172] -->|TRUE| C3
#         I3[IN0173] -->|TRUE| C3
#         C3 -->|TRUE| E3[MF03 = TRUE]
#         C3 -->|FALSE| F3[MF03 維持 FALSE]
#
#         E1 -->|TRUE| C4{任一MF為TRUE}
#         E2 -->|TRUE| C4
#         E3 -->|TRUE| C4
#         C4 -->|TRUE| K4[K1 = TRUE]
#         C4 -->|FALSE| K5[K1 維持 FALSE]
#     end
# ```

# %% [markdown]
# # RCMT-TAKAO-SEQ003-NV2124
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[NOT-DI0074] -->|TRUE| C2{任一訊號為TRUE}
#         G2[IN0167] -->|TRUE| C2
#         H2[IN0139] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[VI002 = TRUE]
#     C4 -->|FALSE| K5[VI002 維持 FALSE]
#     end
# ```
# ### ZO0074(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報
# ```mermaid
#     flowchart LR
#         A3[IX0001] -->|TRUE| A4[ZO0074]
#         B3[DB0074] -->|TRUE| B4[DI1002]
#         D3[NOT-DB0074] -->|TRUE| D4[UA0252]
# ```

# %% [markdown]
# # RCMT-TAKAO-SEQ004-NV2123
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0154] -->|TRUE| C2{任一訊號為TRUE}
#         G2[IX000] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[VI002 = TRUE]
#     C4 -->|FALSE| K5[VI002 維持 FALSE]
#     end
# ```
# ### ZO0075(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報
# ```mermaid
#     flowchart LR
#         A3[IX0001] -->|TRUE| A4[ZO0075]
#         B3[DB0075] -->|TRUE| B4[DI1003]
#         D3[NOT-DB0075] -->|TRUE| D4[UA02523]
# ```

# %% [markdown]
# # RCMT-TAKAO-SEQ005-E180
# # MF01
# ```mermaid
# flowchart LR
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
# ```
# # 連鎖警報
# ```mermaid
# flowchart LR
#         A2[NOT-DI0069] -->|TRUE| C3{訊號同時為TRUE}
#         G2[IN0302] -->|TRUE| C3
#         C3 -->|TRUE| E3[UA0069 = TRUE]
#         style C3 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#
#         A4[NOT-IN0302] -->|TRUE| C4{訊號同時為TRUE}
#         G4[IN0125] -->|TRUE| C4
#         C4 -->|TRUE| E4[UA0125 = TRUE]
#         style C4 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
# ```
#
#
# # MF02
# ```mermaid
# flowchart LR
#         A5[IN0150] -->|TRUE| C5{任一訊號為TRUE}
#         B5[UA0069] -->|TRUE| C5
#         D5[UA0125] -->|TRUE| C5
#         G5[IN0130] -->|TRUE| C5
#         H5[IN0143] -->|TRUE| C5
#         I5[IN0133] -->|TRUE| C5
#         J5[IN0132] -->|TRUE| C5
#         K5[NOT-DI0045] -->|TRUE| C5
#         C5 -->|TRUE| E5[MF02 = TRUE]
#         C5 -->|FALSE| F5[MF02 維持 FALSE]
# ```

# %% [markdown]
# # RCMT-TAKAO-SEQ006-G180
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0150] -->|TRUE| C2{任一訊號為TRUE}
#         B2[UA0069] -->|TRUE| C2
#         D2[UA0125] -->|TRUE| C2
#         G2[IN0130] -->|TRUE| C2
#         H2[IN0143] -->|TRUE| C2
#         I2[IN0133] -->|TRUE| C2
#         K2[DI0045] -->|TRUE| C2
#         C2 -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#    subgraph MF03判斷
#         direction LR
#         A3[NOT-DI0033] -->|TRUE| C3{任一訊號為TRUE}
#         B3[IX000] -->|TRUE| C3
#         C3 -->|TRUE| E3[MF03 = TRUE]
#         C3 -->|FALSE| F3[MF03 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     E3 --> C4
#     C4 -->|TRUE| E4[VI002 = TRUE]
#     C4 -->|FALSE| F4[VI002 維持 FALSE]
#     end
# ```
# ### 警報復歸
# ```mermaid
#     flowchart LR
#         A4[UA0255] -->|TRUE| B4[DO0040=1]
# ```

# %% [markdown]
# # RCMT-TAKAO-SEQ007-FV1111
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0150] -->|TRUE| C2{任一訊號為TRUE}
#         B2[NOT-DI0067] -->|TRUE| C2
#         D2[IN0130] -->|TRUE| C2
#         G2[IN0124] -->|TRUE| C2
#         C2 -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#    subgraph MF03判斷
#         direction LR
#         A3[IN0166] -->|TRUE| C3{任一訊號為TRUE}
#         B3[IX000] -->|TRUE| C3
#         C3 -->|TRUE| E3[MF03 = TRUE]
#         C3 -->|FALSE| F3[MF03 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     E3 --> C4
#     C4 -->|TRUE| E4[UA0256=1<br>BL0002=1 啟動BLS演算]
#     end
# ```
# ### 警報復歸
# ```mermaid
#     flowchart LR
#         A4[UA0256] -->|TRUE| B4[DO0071=1]
# ```
