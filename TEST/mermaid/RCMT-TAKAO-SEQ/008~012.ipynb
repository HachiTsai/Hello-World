# %% [markdown]
# # SEQ008-NV1102
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[UA0069] -->|TRUE| C2{任一訊號為TRUE}
#         B2[IX000] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[VI004 = TRUE]
#     C4 -->|FALSE| K5[VI004 維持 FALSE]
#     end
# ```
# ### ZO0074(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報
# ```mermaid
#     flowchart LR
#         A3[IX0001] -->|TRUE| A4[ZO0067]
#         B3[DB0067] -->|TRUE| B4[DI1002]
#         D3[NOT-DB0067] -->|TRUE| D4[UA0257]
# ```

# %% [markdown]
# # SEQ009-FV1122
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     M1[IX001] --> C4
#     C4 -->|TRUE| K4[UA0258 = TRUE<br>BL003 = TRUE]
#     end
# ```
# ## 警報復歸
# ```mermaid
#     flowchart LR
#         A4[NOT-UA0258] -->|TRUE| B4[DO0073=TRUE]
# ```

# %% [markdown]
# # SEQ010-FV1301
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#         style A1 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#         style B1 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#         style D1 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#     end
#
#     subgraph MF02判斷
#         A2[IN0174] -->|TRUE| C2{任一訊號為TRUE}
#         B2[IX000] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[UA0259 = TRUE<br>BL004 = TRUE]
#     end
# ```
# ## 警報復歸
# ```mermaid
#     flowchart LR
#         A4[NOT-UA0259] -->|TRUE| B4[DO0070=TRUE]
#     style A4 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
# ```

# %% [markdown]
# # SEQ011-FV4001
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#         style A1 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#         style B1 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#         style D1 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#     end
#
#     subgraph MF02判斷
#         A2[IN0175] -->|TRUE| C2{任一訊號為TRUE}
#         B2[IN0176] -->|TRUE| C2
#         D2[NOT-DI0036] -->|TRUE| C2
#         G2[IN0110] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#         style D2 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[UA0260 = TRUE<br>BL005 = TRUE]
#     end
# ```
# ## 警報復歸
# ```mermaid
#     flowchart LR
#         A4[NOT-UA0260] -->|TRUE| B4[DO0069=TRUE]
#     style A4 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
# ```

# %% [markdown]
# # SEQ012-E130
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[NOT-DB0049] -->|TRUE| C1{任一訊號為TRUE}
#         B1[NOT-DI0093] -->|TRUE| C1
#         D1[NOT-DI0001] -->|TRUE| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#         style A1 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#         style B1 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#         style D1 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#     end
#
#     subgraph MF02判斷
#         A2[IN0111] -->|TRUE| C2{任一訊號為TRUE}
#         D2[NOT-DI0049] -->|TRUE| C2
#         G2[IN0174] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#         style D2 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[UA0261 = TRUE]
#     end
# ```
# ## 警報復歸
# ```mermaid
#     flowchart LR
#         A4[NOT-UA0261] -->|TRUE| B4[DO0038=TRUE]
#     style A4 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
# ```
