# %%
import sqlite3
conn = sqlite3.connect('demo.sqlite') # 這邊記得改檔案
cursor = conn.cursor()

# 建立 products 表格（含預設值）
cursor.execute('''
CREATE TABLE IF NOT EXISTS products (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    price REAL DEFAULT 0.0
);
''')

# 建立索引
cursor.execute("CREATE INDEX IF NOT EXISTS idx_products_name ON products(name);")

# 查詢確認
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())

# 查詢資料表內容
cursor.execute("SELECT * FROM products LIMIT 5;")
for row in cursor.fetchall():
    print(row)

# 查看索引狀態
cursor.execute("PRAGMA index_list('products');")
print(cursor.fetchall())

# 查看外鍵設定
cursor.execute("PRAGMA foreign_key_list('orders');")
print(cursor.fetchall())

# 查看外鍵功能有無開啟
cursor.execute("PRAGMA foreign_keys = ON;")

# 檢查欄位屬性與預設值
cursor.execute("PRAGMA table_info('products');")
for col in cursor.fetchall():
    print(col)


conn.commit()
conn.close()
# Out:
# [('products',), ('sqlite_sequence',)]
# (1, 'Laptop', 1500.0, 0.0)
# (2, 'Keyboard', 100.0, 0.0)
# (3, 'Mouse', 350.0, 0.0)
# (4, 'Monitor', 4200.0, 0.0)
# [(0, 'idx_products_name', 0, 'c', 0), (1, 'name', 0, 'c', 0), (2, 'idx_name', 0, 'c', 0)]
# []
# (0, 'id', 'INTEGER', 0, None, 1)
# (1, 'name', 'TEXT', 1, None, 0)
# (2, 'price', 'REAL', 0, None, 0)
# (3, 'discount', 'REAL', 0, '0', 0)
