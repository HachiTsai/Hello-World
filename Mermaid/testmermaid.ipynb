# %% [markdown]
# # Mermaid官方網站
# https://mermaid.js.org/syntax/classDiagram.html

# %%
# 必須升級 ipython ---%pip install --upgrade jupyter ipykernel

# %pip install mkdocs
# %pip install mkdocs-material-extensions
# %pip install mkdocs-jupyter
# %pip install mkdocs-material
# Out:
# Requirement already satisfied: mkdocs in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: click>=7.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (8.2.1)
# Requirement already satisfied: ghp-import>=1.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (2.1.0)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (3.1.6)
# Requirement already satisfied: markdown>=3.3.6 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (3.8.2)
# Requirement already satisfied: markupsafe>=2.0.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (3.0.2)
# Requirement already satisfied: mergedeep>=1.3.4 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (1.3.4)
# Requirement already satisfied: mkdocs-get-deps>=0.2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (0.2.0)
# Requirement already satisfied: packaging>=20.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (25.0)
# Requirement already satisfied: pathspec>=0.11.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (0.12.1)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (1.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (6.0.2)
# Requirement already satisfied: watchdog>=2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ghp-import>=1.0->mkdocs) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-get-deps>=0.2.0->mkdocs) (4.3.8)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->ghp-import>=1.0->mkdocs) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mkdocs-material-extensions in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mkdocs-jupyter in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (0.25.1)
# Requirement already satisfied: ipykernel<7.0.0,>6.0.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-jupyter) (6.30.1)
# Requirement already satisfied: jupytext<2,>1.13.8 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-jupyter) (1.17.2)
# Requirement already satisfied: mkdocs-material>9.0.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-jupyter) (9.6.16)
# Requirement already satisfied: mkdocs<2,>=1.4.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-jupyter) (1.6.1)
# Requirement already satisfied: nbconvert<8,>=7.2.9 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-jupyter) (7.16.6)
# Requirement already satisfied: pygments>2.12.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-jupyter) (2.19.2)
# Requirement already satisfied: appnope>=0.1.2 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (9.4.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (1.6.0)
# Requirement already satisfied: packaging>=22 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (25.0)
# Requirement already satisfied: psutil>=5.7 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (27.0.1)
# Requirement already satisfied: tornado>=6.2 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (5.14.3)
# Requirement already satisfied: markdown-it-py>=1.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jupytext<2,>1.13.8->mkdocs-jupyter) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jupytext<2,>1.13.8->mkdocs-jupyter) (0.4.2)
# Requirement already satisfied: nbformat in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jupytext<2,>1.13.8->mkdocs-jupyter) (5.10.4)
# Requirement already satisfied: pyyaml in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jupytext<2,>1.13.8->mkdocs-jupyter) (6.0.2)
# Requirement already satisfied: click>=7.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs<2,>=1.4.0->mkdocs-jupyter) (8.2.1)
# Requirement already satisfied: ghp-import>=1.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs<2,>=1.4.0->mkdocs-jupyter) (2.1.0)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs<2,>=1.4.0->mkdocs-jupyter) (3.1.6)
# Requirement already satisfied: markdown>=3.3.6 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs<2,>=1.4.0->mkdocs-jupyter) (3.8.2)
# Requirement already satisfied: markupsafe>=2.0.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs<2,>=1.4.0->mkdocs-jupyter) (3.0.2)
# Requirement already satisfied: mergedeep>=1.3.4 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs<2,>=1.4.0->mkdocs-jupyter) (1.3.4)
# Requirement already satisfied: mkdocs-get-deps>=0.2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs<2,>=1.4.0->mkdocs-jupyter) (0.2.0)
# Requirement already satisfied: pathspec>=0.11.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs<2,>=1.4.0->mkdocs-jupyter) (0.12.1)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs<2,>=1.4.0->mkdocs-jupyter) (1.1)
# Requirement already satisfied: watchdog>=2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs<2,>=1.4.0->mkdocs-jupyter) (6.0.0)
# Requirement already satisfied: beautifulsoup4 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from nbconvert<8,>=7.2.9->mkdocs-jupyter) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=7.2.9->mkdocs-jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from nbconvert<8,>=7.2.9->mkdocs-jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from nbconvert<8,>=7.2.9->mkdocs-jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from nbconvert<8,>=7.2.9->mkdocs-jupyter) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from nbconvert<8,>=7.2.9->mkdocs-jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from nbconvert<8,>=7.2.9->mkdocs-jupyter) (1.5.0)
# Requirement already satisfied: webencodings in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=7.2.9->mkdocs-jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=7.2.9->mkdocs-jupyter) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ghp-import>=1.0->mkdocs<2,>=1.4.0->mkdocs-jupyter) (2.9.0.post0)
# Requirement already satisfied: decorator in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (3.0.51)
# Requirement already satisfied: stack_data in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (4.14.1)
# Requirement already satisfied: wcwidth in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (4.3.8)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from markdown-it-py>=1.0->jupytext<2,>1.13.8->mkdocs-jupyter) (0.1.2)
# Requirement already satisfied: babel~=2.10 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material>9.0.0->mkdocs-jupyter) (2.17.0)
# Requirement already satisfied: backrefs~=5.7.post1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material>9.0.0->mkdocs-jupyter) (5.9)
# Requirement already satisfied: colorama~=0.4 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material>9.0.0->mkdocs-jupyter) (0.4.6)
# Requirement already satisfied: mkdocs-material-extensions~=1.3 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material>9.0.0->mkdocs-jupyter) (1.3.1)
# Requirement already satisfied: paginate~=0.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material>9.0.0->mkdocs-jupyter) (0.5.7)
# Requirement already satisfied: pymdown-extensions~=10.2 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material>9.0.0->mkdocs-jupyter) (10.16.1)
# Requirement already satisfied: requests~=2.26 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material>9.0.0->mkdocs-jupyter) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests~=2.26->mkdocs-material>9.0.0->mkdocs-jupyter) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests~=2.26->mkdocs-material>9.0.0->mkdocs-jupyter) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests~=2.26->mkdocs-material>9.0.0->mkdocs-jupyter) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests~=2.26->mkdocs-material>9.0.0->mkdocs-jupyter) (2025.8.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from nbformat->jupytext<2,>1.13.8->mkdocs-jupyter) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from nbformat->jupytext<2,>1.13.8->mkdocs-jupyter) (4.25.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->jupytext<2,>1.13.8->mkdocs-jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->jupytext<2,>1.13.8->mkdocs-jupyter) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->jupytext<2,>1.13.8->mkdocs-jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->jupytext<2,>1.13.8->mkdocs-jupyter) (0.26.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->ghp-import>=1.0->mkdocs<2,>=1.4.0->mkdocs-jupyter) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert<8,>=7.2.9->mkdocs-jupyter) (2.7)
# Requirement already satisfied: executing>=1.2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel<7.0.0,>6.0.0->mkdocs-jupyter) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mkdocs-material in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (9.6.16)
# Requirement already satisfied: babel~=2.10 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (2.17.0)
# Requirement already satisfied: backrefs~=5.7.post1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (5.9)
# Requirement already satisfied: colorama~=0.4 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (0.4.6)
# Requirement already satisfied: jinja2~=3.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (3.1.6)
# Requirement already satisfied: markdown~=3.2 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (3.8.2)
# Requirement already satisfied: mkdocs-material-extensions~=1.3 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (1.3.1)
# Requirement already satisfied: mkdocs~=1.6 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (1.6.1)
# Requirement already satisfied: paginate~=0.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (0.5.7)
# Requirement already satisfied: pygments~=2.16 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (2.19.2)
# Requirement already satisfied: pymdown-extensions~=10.2 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (10.16.1)
# Requirement already satisfied: requests~=2.26 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-material) (2.32.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from jinja2~=3.1->mkdocs-material) (3.0.2)
# Requirement already satisfied: click>=7.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs~=1.6->mkdocs-material) (8.2.1)
# Requirement already satisfied: ghp-import>=1.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs~=1.6->mkdocs-material) (2.1.0)
# Requirement already satisfied: mergedeep>=1.3.4 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs~=1.6->mkdocs-material) (1.3.4)
# Requirement already satisfied: mkdocs-get-deps>=0.2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs~=1.6->mkdocs-material) (0.2.0)
# Requirement already satisfied: packaging>=20.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs~=1.6->mkdocs-material) (25.0)
# Requirement already satisfied: pathspec>=0.11.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs~=1.6->mkdocs-material) (0.12.1)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs~=1.6->mkdocs-material) (1.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs~=1.6->mkdocs-material) (6.0.2)
# Requirement already satisfied: watchdog>=2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs~=1.6->mkdocs-material) (6.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests~=2.26->mkdocs-material) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests~=2.26->mkdocs-material) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests~=2.26->mkdocs-material) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests~=2.26->mkdocs-material) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from ghp-import>=1.0->mkdocs~=1.6->mkdocs-material) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.2.0 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from mkdocs-get-deps>=0.2.0->mkdocs~=1.6->mkdocs-material) (4.3.8)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->ghp-import>=1.0->mkdocs~=1.6->mkdocs-material) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ```mermaid
# graph LR
#     A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#     B1[D0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
# ```

# %% [markdown]
# ```mermaid
# ---
# title: Animal example
# ---
# classDiagram
#     note "From Duck till Zebra"
#     Animal <|-- Duck
#     note for Duck "can fly\ncan swim\ncan dive\ncan help in debugging"
#     Animal <|-- Fish
#     Animal <|-- Zebra
#     Animal : +int age
#     Animal : +String gender
#     Animal: +isMammal()
#     Animal: +mate()
#     class Duck{
#         +String beakColor
#         +swim()
#         +quack()
#     }
#     class Fish{
#         -int sizeInFeet
#         -canEat()
#     }
#     class Zebra{
#         +bool is_wild
#         +run()
#     }
# ```

# %% [markdown]
# ```mermaid
# classDiagram
#     class `Animal Class!`
#     class `Car Class`
#     `Animal Class!` --> `Car Class`
# ```

# %% [markdown]
# ```mermaid
# flowchart LR
#     A1[DB0049] -->|"NOT"| C1{{任一訊號為 TRUE}}
#     B1[DI0093] -->|"NOT"| C1
#     C1 -->|TRUE| E1[✅ MF01 = TRUE]
#
#     linkStyle 0 color:red;
#     classDef critical fill:#black,stroke:#ff0000,stroke-width:2px;
#     class A1,B1,E1 critical
# ```
