# %% [markdown]
# # SEQ014-YV4103
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[DI0048] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2{任一訊號為TRUE}
#         B2[DI0065] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         D2[DI0075] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[VI004 = TRUE]
#     C4 -->|FALSE| K5[VI004 維持 FALSE]
#     end
# ```
# ### ZO0065(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報
# ```mermaid
#     flowchart LR
#         A3[IX0001] -->|TRUE| A4[ZO0065=1=M]
#         A4 -->B3[DB0065=0=M] -->|DB0065=0| B4[DI1005=1<br>UA0263=0]
#         B3 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT DB0065=1</font>"| D4[DI1005=0<br>UA0263=1]
# ```

# %% [markdown]
# # SEQ015-YV4203
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[DI0032] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2{任一訊號為TRUE}
#         B2[DI0068] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         D2[DI0076] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[VI004 = TRUE]
#     C4 -->|FALSE| K5[VI004 維持 FALSE]
#     end
# ```
# ### ZO0066(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報
# ```mermaid
#     flowchart LR
#         A3[IX0001] -->|TRUE| A4[ZO0066=1=M]
#         A4 -->B3[DB0066=0=M] -->|DB0066=0| B4[DI1006=1<br>UA0264=0]
#         B3 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT DB0066=1</font>"| D4[DI1006=0<br>UA0264=1]
# ```

# %% [markdown]
# # SEQ016-YV4503
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         M1[IN0109] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[DI0058] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2{任一訊號為TRUE}
#         B2[DI0066] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         D2[DI0077] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[VI004 = TRUE]
#     C4 -->|FALSE| K5[VI004 維持 FALSE]
#     end
# ```
# ## ZO0064(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報
# ```mermaid
#     flowchart LR
#         A3[IX0001] -->|TRUE| A4[ZO0064=1=M]
#         A4 -->B3[DB0064=0=M] -->|DB0064=0| B4[DI1007=1<br>UA0265=0]
#         B3 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT DB0064=1</font>"| D4[DI1007=0<br>UA0265=1]
# ```

# %% [markdown]
# # SEQ017-PV4375
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0151] -->|TRUE| C2{任一訊號為TRUE}
#         B2[IX000] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[VI008 = TRUE]
#     end
# ```
# ## ZO0068(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報
# ```mermaid
#     flowchart LR
#         A3[IX0001] -->|TRUE| A4[ZO0068=1=M]
#         A4 -->B3[DB0068=0=M] -->|DB0068=0| B4[DI1008=1<br>UA0266=0]
#         B3 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT DB0068=1</font>"| D4[DI1008=0<br>UA0266=1]
# ```

# %% [markdown]
# # SEQ018-FV1200
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     M1[IX001] --> C4
#     C4 -->|TRUE| K4[UA0267 = TRUE]
#     C4 -->|TRUE| K5[BL006 = TRUE]
#     end
#
#     subgraph 警報復歸
#         K4[UA0267] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| F4[DO0072=TRUE]
#     end
# ```

# %% [markdown]
# # SEQ019-QMAX
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF02判斷
#         A2[IN0104] -->|TRUE| C2{任一訊號為TRUE}
#         G2[IN0105] -->|TRUE| C2
#         C2{任一訊號為TRUE} -->|TRUE| E2[MF02 = TRUE]
#         C2 -->|FALSE| F2[MF02 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#     E1 --> C4{任一MF為TRUE}
#     E2 --> C4
#     C4 -->|TRUE| K4[UA0268 = TRUE]
#     end
#
#     subgraph 警報復歸
#         K4[UA0268] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| F4[DO0043=TRUE]
#     end
# ```

# %% [markdown]
# # SEQ020-G430
#
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         G1[IN0101] -->|TRUE| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0103] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[IN0152] -->|TRUE| C1
#         K1[IN0131] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF條件判斷
#         E1 --> C4{任一MF為TRUE}
#         M1[IX001] --> C4
#         C4 -->|TRUE| K4[UA0269]
#         C4 -->|TRUE| K5[VI009 = TRUE]
#         end
#
#     subgraph 連鎖及警報復歸
#         A3[IX0001] -->|TRUE| A4[ZO0035=1=M]
#         K4 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| D4[DO0042]
#         A4 -->B3[DB0035=0=M] -->|DB0035=0| B4[DI1009=1<br>UA0270=0]
#         B3 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT DB0035=1</font>"| J4[DI1009=0<br>UA0270=1]
#     end
# ```
# ## ZO0035(A/M mode; 0=A / 1=M)常時為1,若不等於1 則發警報(如上)

# %% [markdown]
# # SEQ021-GDR1-3
#
# ```mermaid
#     flowchart LR
#     direction LR
#     subgraph MF01
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         H1[IN0102] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01]
#         C1 -->|FALSE| F1[MF01 維持 FALSE]
#     end
#
#     subgraph MF01 連鎖開啟閥門
#         E1 --> C4{任一訊號為TRUE}
#         B2[IX000] --> C4
#         C4 --> C5["<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"]
#         C5 -->K10[DO0050 = TRUE]
#         C5 -->K11[DO0051 = TRUE]
#         C5 -->K12[DO0052 = TRUE]
#     end
#
#     subgraph 閥門回饋訊號關閉警報
#         K10 -->K15[DB0050] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C10{全部訊號為TRUE}
#         K11 -->K16[DB0051] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C10{全部訊號為TRUE}
#         K12 -->K17[DB0052] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C10{全部訊號為TRUE}
#         C10 -->|TRUE| E3[UA0271 = TRUE]
#     end
# ```

# %% [markdown]
# # SEQ022-K500 START/OFF
# ## MF01
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0104] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         J1[DI0064] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C1{任一訊號為TRUE} -->|"<font color='black' style='background-color:white;font-style:italic; font-weight:bold'>DI0064 = TRUE</font>"| E10[DI0064 = TRUE = MF01 ]
#     end
#
#     subgraph MF條件判斷
#         E1 --> C4{任一MF為TRUE}
#         M1[IX000] --> C4
#         C4 -->|TRUE| K4[UA0275]
#     end
#
#     subgraph 警報復歸
#         K4 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| F4[DO0078 = TRUE<br>DO0077 = TRUE]
#     end
#
#     subgraph 警報復歸
#         E10 -->|TRUE| E4[UA0272 = TRUE]
#         E10 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| G4[UA0273 = TRUE]
#     end
# ```
#
# ## MF02
# ```mermaid
# flowchart LR
#     subgraph MF01判斷
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         H1[IN0102] -->|TRUE| C1
#         I1[IN0104] -->|TRUE| C1
#         L1[IN0108] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF02 = TRUE]
#     end
#
#     subgraph MF條件判斷
#         E1 --> C4{任一MF為TRUE}
#         M1[IX000] --> C4
#         C4 -->|TRUE| K4[UA0274]
#     end
#
#     subgraph 警報復歸
#         K4 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| F4[DO0032 = TRUE<br>DO0045 = TRUE]
#     end
# ```

# %% [markdown]
# # SEQ023-YL5000SEQ LOCAL LAMP SEQ
#
# ```mermaid
# flowchart LR
#     subgraph MF01
#         A1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         H1[IN0101] -->|TRUE| C1
#         I1[IN0102] -->|TRUE| C1
#         L1[IN0103] -->|TRUE| C1
#         J1[IN0104] -->|TRUE| C1
#         K1[IN0105] -->|TRUE| C1
#         M1[IN0106] -->|TRUE| C1
#         N1[IN0107] -->|TRUE| C1
#         O1[IN0108] -->|TRUE| C1
#         P1[IN0109] -->|TRUE| C1
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01]
#     end
#
#     subgraph INTERLOCK
#         E1 -->|TRUE| C2{任一訊號為NOT}
#         B2[IX0000] -->|TRUE| C2
#         C2 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| K4[DO0036 = TRUE]
#         style C2 fill:#fff,stroke:#333,stroke-width:1px,color:#ff0000
#     end
# ```
#
# ```mermaid
# flowchart LR
#         A4[DI0070] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C4[訊號同時為TRUE]
#         B4[DI0064] -->|TRUE| C4
#         C4 -->|TRUE| E4[DO0086 = TRUE]
# ```
#
# ```mermaid
# flowchart LR
#         A5[IN0142] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C10[DO0076 = TRUE]
# ```

# %% [markdown]
# # SEQ024-NV9900SEQ FIRE WATER OPEN SEQ
#
# ```mermaid
#     flowchart LR
#         A1[IN0201] -->|TRUE| C1[DO0079 = TRUE]
#         A1 -->|TRUE| C11[UA0277 = TRUE]
#         C1 -->B1[DB0079<br>=DO0079 A/M mode] -->|TRUE| C2[DI1015 = TRUE]
#         D1[IN0203] -->|TRUE| C3[DO0080 = TRUE]
#         D1 -->|TRUE| C33[UA0278 = TRUE]
#         C3 -->E1[DB0080<br>=DO0080 A/M mode] -->|TRUE| C4[DI1016 = TRUE]
#         F1[IN0206] -->|TRUE| C5{任一訊號為TRUE}
#         G1[IN0207] -->|TRUE| C5
#         C5 -->|TRUE| C6[DO0081 = TRUE]
#         C5 -->|TRUE| C66[UA0276 = TRUE]
#         C6 -->H1[DB0081<br>=DO0081 A/M mode] -->|TRUE| C8[DI1017 = TRUE]
# ```

# %% [markdown]
# # SEQ025-ALHORNEQSEQ ALARM HORN SEQ
#
# ## MF04 為自保持迴路
# ```mermaid
#     flowchart LR
#         A1[DB0049-oneshot1] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1{任一訊號為TRUE}
#         B1[DI0093-oneshot2] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         D1[DI0001-oneshot12] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C1
#         H1[IN0101-oneshot3] -->|TRUE| C2{任一訊號為TRUE}
#         I1[IN0102-oneshot4] -->|TRUE| C2
#         L1[IN0103-oneshot5] -->|TRUE| C2
#         J1[IN0104-oneshot6] -->|TRUE| C2
#         K1[IN0105-oneshot7] -->|TRUE| C2
#         M1[IN0106-oneshot8] -->|TRUE| C2
#         N1[IN0107-oneshot9] -->|TRUE| C2
#         O1[IN0108-oneshot10] -->|TRUE| C2
#         P1[IN0109-oneshot11] -->|TRUE| C2
#         C1{任一訊號為TRUE} -->|TRUE| E1[MF01 = TRUE]
#         C2 -->|TRUE| E2[MF02 = TRUE]
#         E1 -->|TRUE| E3[任一訊號為TRUE]
#         E2 -->|TRUE| E3
#         E4[MF04] -->|"<font color='green' style='background-color:white'>TRUE</font>"| E3
#         E3 -->|TRUE| E11[全部訊號為TRUE]
#         E11 -->|TRUE| E4
#         E4 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| C3[DO0044 = TRUE]
#         R1[IN0301] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| E11
# ```

# %% [markdown]
# # SEQ026-WWNVEQ WASTE WATER VALVE SEQ
#
# ```mermaid
#     flowchart LR
#         A1[IN0115] -->|TRUE| C1[DO0082 = TRUE]
#         A1 -->|TRUE| C10[DO0083 = TRUE]
#         C1 -->B1[DB0082] -->|TRUE| C2[DI1013 = TRUE]
#         C10 -->D1[DB0083] -->|TRUE| C3[DI1014 = TRUE]
#         E1[IX001] -->|TRUE| C4[ZO0084 = TRUE]
#         C4 -->F1[DB0084] -->|TRUE| C5[DI1011]
#         G1[IX001] -->|TRUE| C6[ZO0085]
#         C6 -->H1[DB0085] -->|TRUE| C7[DI1012]
# ```

# %% [markdown]
# # SEQ027-WWPMEQ WASTE WATER PUMP SEQ
#
# ```mermaid
#     flowchart LR
#         %%第1,2個計時器%%
#         A1[DI0078] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| T1[TD0001 = TRUE<br>Time Count Start]
#         B1[DI0079] -->|TRUE| T2[TD0002 = TRUE<br>Time Count Start]
#         T1 -->|"<font color='blue' style='background-color:white;font-style:italic; font-weight:bold'>TU0001<br>CountUP</font>"| E1{任一訊號為TRUE}
#         D1[DO0046] --> E1
#         E1 -->E2[全部訊號為TRUE]
#         T2 -->|"<font color='blue' style='background-color:white;font-style:italic; font-weight:bold'>TU002<br>CountUP</font>"| E2
#         F1[DB0049] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| E5{任一訊號為TRUE}
#         F2[DI0093] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| E5
#         F3[DI0001] -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| E5
#         E5 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| E2
#         E2 -->|TRUE| E10[DO0046 = TRUE<br>DO0047 = TRUE]
#         %%第3個計時器%%
#         G1[DI0073] -->T3[TD0003 = TRUE<br>Time Count Start]
#         T3 -->|"<font color='blue' style='background-color:white;font-style:italic; font-weight:bold'>TU0003<br>CountUP</font>"| E15[全部訊號為TRUE]
#         E15 --> C3[DO0048]
#         F1 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| E13{任一訊號為TRUE}
#         F2 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| E13
#         F3 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| E13
#         E13 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| E15
#         C3 -->|"<font color='red' style='background-color:white;font-style:italic; font-weight:bold'>NOT</font>"| E20[UA0282 = TRUE]
# ```
